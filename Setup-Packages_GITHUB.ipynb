# %% [markdown]
# ## Python Packages Setup
# ### For data manipulation/read-write or data analysis
# <ul>
#     <li> <img src="https://pandas.pydata.org/docs/_static/pandas.svg" alt="Pandas Logo" width="100"> <br>
#     Pandas is a Python library renowned for its fast and efficient DataFrame object, optimized for data manipulation and integrated indexing. It excels in reading and writing data across various formats such as CSV, Excel, SQL databases, and HDF5, facilitating seamless data interchange. The library offers intelligent data alignment and robust handling of missing data, enabling automatic label-based alignment in computations and simplifying the organization of disparate data sources. Pandas supports flexible reshaping, advanced slicing techniques, and powerful group-by operations, making it indispensable across diverse domains including Finance, Neuroscience, Economics, Statistics, Advertising, and Web Analytics. <br>
#     🗎 <a href="https://pandas.pydata.org">https://pandas.pydata.org/</a>
#     </li><br>
#     <li> <img src="https://numpy.org/doc/stable/_static/numpylogo.svg" alt="NumPy Logo" width="100"> <br>
#     NumPy is a fundamental Python library for numerical computing, providing support for large, multi-dimensional arrays and matrices. It includes a wide range of mathematical functions to operate on these arrays efficiently. NumPy's key features include broadcasting, which enables element-wise operations across arrays of different shapes, and universal functions (ufuncs) for fast computation. It serves as a foundation for many scientific computing tasks in fields such as machine learning, data analysis, and engineering simulations, offering performance optimizations with its underlying implementation in C.<br>
#     🗎 <a href = "https://numpy.org/doc/stable/"> https://numpy.org/doc/stable/ </a>
#     </li> <br>
#     <li> <img src="https://scipy.org/images/logo.svg" alt="SciPy Logo" width="100"> <br>
#     SciPy is a Python library built on NumPy, offering additional tools for scientific and technical computing. It includes modules for optimization, integration, interpolation, linear algebra, and statistical operations. SciPy extends NumPy's capabilities with advanced functions and algorithms tailored for scientific research and engineering applications. The library supports efficient manipulation and analysis of scientific data, making it indispensable in fields like physics, biology, chemistry, and signal processing.<br>
#     🗎 <a href = "https://docs.scipy.org/doc/scipy/"> https://docs.scipy.org/doc/scipy/</a> <br>
#     </li> <br>
#
#
# ### For plotting data
# <ul>
#     <li> <img src="https://matplotlib.org/_static/logo_dark.svg" alt="Matplotlib Logo" width="100"> <br>
# Matplotlib is a comprehensive Python library for creating static, animated, and interactive visualizations. It offers a wide range of plotting capabilities for generating plots, charts, histograms, scatterplots, and more. Matplotlib integrates seamlessly with NumPy and other Python libraries, providing a flexible API for customizing visualizations with labels, legends, colors, and annotations. Widely used in scientific research, data analysis, and presentation of data insights, Matplotlib supports both 2D and 3D plotting, making it a versatile tool for visualizing data in various domains.<br>
#     🗎 <a href = "https://matplotlib.org/stable/users/index"> https://matplotlib.org/stable/users/index</a> <br>
#  </li><br>
#     <li> <img src="https://seaborn.pydata.org/_static/logo-wide-lightbg.svg" alt="Seaborn Logo" width="100"> <br>
#     Seaborn is a Python visualization library built on top of Matplotlib, specializing in creating attractive and informative statistical graphics. It simplifies the creation of complex visualizations such as categorical plots, distribution plots, and regression plots with minimal code. Seaborn enhances Matplotlib's default aesthetics and provides built-in themes and color palettes for visually appealing plots. It excels in exploring relationships in datasets through advanced statistical techniques and is widely used in statistical modeling, data exploration, and machine learning tasks. <br>
#     🗎 <a href = "https://seaborn.pydata.org/"> https://seaborn.pydata.org/ </a> <br>
#     </li><br>
#     <li> <img src="https://images.prismic.io/plotly-marketing-website-2/8f977c91-7b4e-4367-8228-26fbba2506e4_69e12d6a-fb65-4b6e-8423-9465a29c6028_plotly-logo-sm.png?auto=compress%2Cformat&fit=max&w=128" alt="Plotly Logo" width="100"> <br>
# Plotly is a versatile Python library for creating interactive and publication-quality visualizations. It supports a wide range of chart types including line charts, bar charts, scatter plots, and heatmaps, with built-in interactivity like zooming, panning, and tooltips. Plotly can generate both static images and interactive web-based visualizations that can be embedded in web applications or shared online. It integrates seamlessly with Pandas DataFrames and NumPy arrays, making it suitable for analyzing and visualizing data in scientific research, business analytics, and data-driven applications. <br>
#   🗎 <a href = "https://plotly.com/graphing-libraries/"> https://plotly.com/graphing-libraries/ </a> <br>
#     </li><br>
# </ul>
#
# ### For performing ML
# <ul>
#     <li> <img src="https://scikit-learn.org/stable/_static/scikit-learn-logo-small.png" alt="Scikit-learn Logo" width="100"> <br>
# Scikit-learn is a comprehensive Python library for machine learning, providing tools for data preprocessing, supervised and unsupervised learning algorithms, and model evaluation. It offers a consistent API for training and deploying machine learning models, with support for various tasks such as classification, regression, clustering, and dimensionality reduction. Scikit-learn integrates seamlessly with other Python libraries like NumPy, SciPy, and Pandas, enabling efficient data manipulation and statistical operations. Widely used in academia and industry, scikit-learn simplifies complex machine learning workflows and promotes reproducible research through accessible and well-documented implementations of algorithms.<br>
#   🗎 <a href = "https://scikit-learn.org/stable/user_guide.html"> https://scikit-learn.org/stable/user_guide.html </a> <br>
#     </li> <br>
#     <li> <img src="https://www.tensorflow.org/images/tf_logo_social.png" alt="TensorFlow Logo" width="100"> <br>
# TensorFlow is an open-source machine learning framework developed by Google for building and training deep neural networks. It provides a comprehensive ecosystem with tools for data preprocessing, model building, training, deployment, and production-scale inference. TensorFlow supports both CPU and GPU computation, optimizing performance for large-scale data processing and complex model architectures. With its flexible architecture, TensorFlow enables researchers and developers to experiment with cutting-edge machine learning techniques and deploy scalable machine learning solutions across various domains including computer vision, natural language processing, and reinforcement learning.<br>
#   🗎 <a href = "https://www.tensorflow.org/learn"> https://www.tensorflow.org/learn </a> <br>
#     </li><br>
#     <li> <img src="https://keras.io/img/logo.png" alt="Keras Logo" width="100"><br>
#     <br>
#     Keras is a high-level neural networks API written in Python, designed for fast experimentation with deep learning models. It provides a user-friendly interface to build, train, and deploy neural networks with minimal code. Keras supports both CPU and GPU acceleration, seamlessly integrating with TensorFlow, Theano, and Microsoft Cognitive Toolkit (CNTK) backends. With its modular architecture, Keras allows for easy prototyping and customization of neural network architectures, making it accessible for both beginners and experienced machine learning practitioners alike.<br>
#   🗎 <a href = "https://keras.io/"> https://keras.io/ </a> <br>
#     </li><br>
# </ul>
#
# This content was generated with prompt inputs from [ChatGPT](https://www.openai.com/chatgpt), an AI language model developed by OpenAI.

# %%
pip install pandas numpy scipy scikit-learn seaborn matplotlib tensorflow nbconvert jupyter
# Out:
# Requirement already satisfied: pandas in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (2.0.0)
# Requirement already satisfied: scipy in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (1.14.0)
# Requirement already satisfied: scikit-learn in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (1.5.0)
# Requirement already satisfied: seaborn in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (3.9.0)
# Requirement already satisfied: tensorflow in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (2.16.2)
# Requirement already satisfied: nbconvert in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (7.16.4)
# Requirement already satisfied: jupyter in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (1.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\muthu\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: tensorflow-intel==2.16.2 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (2.16.2)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (18.1.1)
# Collecting ml-dtypes~=0.3.1 (from tensorflow-intel==2.16.2->tensorflow)
#   Using cached ml_dtypes-0.3.2-cp312-cp312-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (3.3.0)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow-intel==2.16.2->tensorflow)
#   Using cached protobuf-4.25.3-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (70.2.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\muthu\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.2->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (1.64.1)
# Collecting tensorboard<2.17,>=2.16 (from tensorflow-intel==2.16.2->tensorflow)
#   Using cached tensorboard-2.16.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: keras>=3.0.0 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.2->tensorflow) (3.4.1)
# Collecting numpy
#   Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from nbconvert) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from nbconvert) (6.1.0)
# Requirement already satisfied: defusedxml in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from nbconvert) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from nbconvert) (3.1.4)
# Requirement already satisfied: jupyter-core>=4.7 in c:\users\muthu\appdata\roaming\python\python312\site-packages (from nbconvert) (5.7.2)
# Requirement already satisfied: jupyterlab-pygments in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from nbconvert) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from nbconvert) (2.1.5)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from nbconvert) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from nbconvert) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from nbconvert) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from nbconvert) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\muthu\appdata\roaming\python\python312\site-packages (from nbconvert) (2.18.0)
# Requirement already satisfied: tinycss2 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from nbconvert) (1.3.0)
# Requirement already satisfied: traitlets>=5.1 in c:\users\muthu\appdata\roaming\python\python312\site-packages (from nbconvert) (5.14.3)
# Requirement already satisfied: notebook in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jupyter) (7.2.1)
# Requirement already satisfied: qtconsole in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jupyter) (5.5.2)
# Requirement already satisfied: jupyter-console in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: ipykernel in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jupyter) (6.29.5)
# Requirement already satisfied: ipywidgets in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jupyter) (8.1.3)
# Requirement already satisfied: webencodings in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from bleach!=5.0.0->nbconvert) (0.5.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\muthu\appdata\roaming\python\python312\site-packages (from jupyter-core>=4.7->nbconvert) (4.2.2)
# Requirement already satisfied: pywin32>=300 in c:\users\muthu\appdata\roaming\python\python312\site-packages (from jupyter-core>=4.7->nbconvert) (306)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from nbclient>=0.5.0->nbconvert) (8.6.2)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from nbformat>=5.7->nbconvert) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from nbformat>=5.7->nbconvert) (4.22.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4->nbconvert) (2.5)
# Requirement already satisfied: comm>=0.1.1 in c:\users\muthu\appdata\roaming\python\python312\site-packages (from ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter) (1.8.2)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter) (8.26.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\muthu\appdata\roaming\python\python312\site-packages (from ipykernel->jupyter) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\muthu\appdata\roaming\python\python312\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: psutil in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter) (6.0.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\muthu\appdata\roaming\python\python312\site-packages (from ipykernel->jupyter) (26.0.3)
# Requirement already satisfied: tornado>=6.1 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyter) (6.4.1)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets->jupyter) (4.0.11)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets->jupyter) (3.0.11)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-console->jupyter) (3.0.47)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from notebook->jupyter) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from notebook->jupyter) (2.27.2)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from notebook->jupyter) (4.2.3)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from notebook->jupyter) (0.2.4)
# Requirement already satisfied: qtpy>=2.4.0 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from qtconsole->jupyter) (2.4.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.2->tensorflow) (0.43.0)
# Requirement already satisfied: decorator in c:\users\muthu\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\muthu\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.1)
# Requirement already satisfied: stack-data in c:\users\muthu\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.3)
# Requirement already satisfied: colorama in c:\users\muthu\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (0.18.1)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (4.4.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.20.0)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (2.0.13)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter) (0.27.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter) (2.2.5)
# Requirement already satisfied: babel>=2.10 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter) (2.15.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter) (0.9.25)
# Requirement already satisfied: rich in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (0.11.0)
# Requirement already satisfied: wcwidth in c:\users\muthu\appdata\roaming\python\python312\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.2->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.2->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.2->tensorflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.2->tensorflow) (2024.6.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.2->tensorflow) (3.0.3)
# Requirement already satisfied: sniffio>=1.1 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter) (21.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\muthu\appdata\roaming\python\python312\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (3.0.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\muthu\appdata\roaming\python\python312\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\muthu\appdata\roaming\python\python312\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\muthu\appdata\roaming\python\python312\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: fqdn in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (24.6.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.2->tensorflow) (0.1.2)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\muthu\appdata\local\programs\python\python312\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.9.0.20240316)
# Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
# Using cached ml_dtypes-0.3.2-cp312-cp312-win_amd64.whl (128 kB)
# Using cached protobuf-4.25.3-cp310-abi3-win_amd64.whl (413 kB)
# Using cached tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
# Installing collected packages: protobuf, numpy, tensorboard, ml-dtypes
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.27.2
#     Uninstalling protobuf-5.27.2:
#       Successfully uninstalled protobuf-5.27.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.0
#     Uninstalling numpy-2.0.0:
#       Successfully uninstalled numpy-2.0.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.17.0
#     Uninstalling tensorboard-2.17.0:
#       Successfully uninstalled tensorboard-2.17.0
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.0
#     Uninstalling ml-dtypes-0.4.0:
#       Successfully uninstalled ml-dtypes-0.4.0
# Successfully installed ml-dtypes-0.3.2 numpy-1.26.4 protobuf-4.25.3 tensorboard-2.16.2
# Note: you may need to restart the kernel to use updated packages.
